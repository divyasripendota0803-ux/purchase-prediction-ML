# %%
#import Required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset
df=pd.read_csv(r"C:\diabetes\Purchase_new.csv")

# %%
df.head(10)
# Out:
#   Holiday Discount Free Delivery Purchase
# 0      No      Yes           Yes      Yes
# 1      No      Yes           Yes      Yes
# 2      No       No            No       No
# 3     yes      Yes           Yes      Yes
# 4     yes      Yes           Yes      Yes
# 5     yes       No            No       No
# 6     yes      Yes            No      Yes
# 7      No      Yes           Yes      Yes
# 8     yes      Yes           Yes      Yes
# 9     yes      Yes           Yes      Yes

# %%
x = df.drop(['Purchase','Holiday','Free Delivery'],axis=1)
y = df['Purchase']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df["Purchase"]=le.fit_transform(df["Purchase"])

# %%
df["Free Delivery"]=le.fit_transform(df["Free Delivery"])

# %%
df["Holiday"]=le.fit_transform(df["Holiday"])

# %%
df["Discount"]=le.fit_transform(df["Discount"])

# %%
df.head(10)
# Out:
#    Holiday  Discount  Free Delivery  Purchase
# 0        0         1              1         1
# 1        0         1              1         1
# 2        0         0              0         0
# 3        1         1              1         1
# 4        1         1              1         1
# 5        1         0              0         0
# 6        1         1              0         1
# 7        0         1              1         1
# 8        1         1              1         1
# 9        1         1              1         1

# %%
df.corr()
# Out:
#                 Holiday  Discount  Free Delivery  Purchase
# Holiday        1.000000 -0.244558      -0.092675 -0.034586
# Discount      -0.244558  1.000000       0.445823  0.530330
# Free Delivery -0.092675  0.445823       1.000000  0.512272
# Purchase      -0.034586  0.530330       0.512272  1.000000

# %%
#divide the data into x and y variable
x=df.drop(columns=['Purchase'],axis=True)
y=df['Purchase']

# %%
x=df.drop(['Purchase','Holiday'],axis=1)
y=df['Purchase']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
#Initialize the decision tree classifier

from sklearn.tree import DecisionTreeClassifier 
dt=DecisionTreeClassifier()

# %%
# train the model
model=dt.fit(x_train,y_train)

# %%
# predict on test set
y_pred=model.predict(x_test)

# %%
# calculation accuracy
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)

# %%
for column in df.columns:
    df[column]=le.fit_transform(df[column])

# %%
print(accuracy)
# Out:
# 1.0

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
dt=DecisionTreeClassifier()

# %%
model=dt.fit(x_train,y_train)
model1=lr.fit(x_train,y_train)
